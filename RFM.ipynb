# %% [markdown]
# ## About The Dataset
#
#
# This dataset represents a series of transactions recorded in an invoice log. Each row corresponds to a unique transaction and contains information such as the invoice number, stock code, description of the item, quantity purchased, date of the invoice, unit price, customer ID, and country of the customer.
#
# The transactions appear to be related to retail sales of various items, including napkins, children's aprons, children's cutlery sets, and a baking set. The transactions all occurred on December 9, 2011, at 12:50 PM. The customer associated with these transactions has an ID of 12680.0 and is located in France.

# %% [markdown]
# ### RFM analysis is a technique used in marketing and customer relationship management to segment and analyze customers based on their recent purchasing behavior. RFM stands for:
#
# 1. **Recency**: How recently a customer has made a purchase. It is often measured in terms of the time since the last purchase.
#
# 2. **Frequency**: How often a customer makes a purchase within a specific period, such as a month or a year.
#
# 3. **Monetary**: The total amount of money a customer has spent within a specific period.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('OnlineRetail.csv', encoding = 'unicode_escape')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.tail(5)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
currentDate = pd.to_datetime("2012-01-01")

df['InvoiceDate']=pd.to_datetime(df["InvoiceDate"])

# %%
currentDate
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.groupby(["CustomerID"]).max()
# Out:
#            InvoiceNo StockCode                        Description  Quantity  \
# CustomerID
# 12346.0      C541433     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 12347.0       581180    85232D   WOODLAND DESIGN  COTTON TOTE BAG       240
# 12348.0       568172      POST                 SWEETIES  STICKERS       144
# 12349.0       577609      POST          ZINC FOLKART SLEIGH BELLS        36
# 12350.0       543037      POST    UNION JACK FLAG PASSPORT COVER         24
# ...              ...       ...                                ...       ...
# 18280.0       545712     82484          WOODEN UNION JACK BUNTING         8
# 18281.0       556464     23209                ROBOT BIRTHDAY CARD        12
# 18282.0      C562808     23295   SET OF 12 MINI LOAF BAKING CASES        48
# 18283.0       580872         M          ZINC FOLKART SLEIGH BELLS        13
# 18287.0       573167     85173  TREE T-LIGHT HOLDER WILLIE WINKIE        60
#
# ...

# %% [markdown]
# #### Here we got the date when each customer buys

# %%
maxdate = df.groupby(["CustomerID"]).max()[['InvoiceDate']]
maxdate
# Out:
#                    InvoiceDate
# CustomerID
# 12346.0    2011-01-18 10:17:00
# 12347.0    2011-12-07 15:52:00
# 12348.0    2011-09-25 13:13:00
# 12349.0    2011-11-21 09:51:00
# 12350.0    2011-02-02 16:01:00
# ...                        ...
# 18280.0    2011-03-07 09:52:00
# 18281.0    2011-06-12 10:53:00
# 18282.0    2011-12-02 11:43:00
# 18283.0    2011-12-06 12:02:00
# 18287.0    2011-10-28 09:29:00
#
# [4372 rows x 1 columns]

# %% [markdown]
# #### Demo for time diff between current date and the date when customer buys .
# Basically how long it's been customer buys .

# %%
(currentDate - maxdate['InvoiceDate']).dt.days
# Out:
# CustomerID
# 12346.0    347
# 12347.0     24
# 12348.0     97
# 12349.0     40
# 12350.0    332
#           ...
# 18280.0    299
# 18281.0    202
# 18282.0     29
# 18283.0     25
# 18287.0     64
# Name: InvoiceDate, Length: 4372, dtype: int64

# %% [markdown]
# Now we are converting all of the columns for getting the age of the invoice .

# %%
maxdate['InvoiceAge'] = (currentDate - maxdate['InvoiceDate']).dt.days
maxdate
# Out:
#                    InvoiceDate  InvoiceAge
# CustomerID
# 12346.0    2011-01-18 10:17:00         347
# 12347.0    2011-12-07 15:52:00          24
# 12348.0    2011-09-25 13:13:00          97
# 12349.0    2011-11-21 09:51:00          40
# 12350.0    2011-02-02 16:01:00         332
# ...                        ...         ...
# 18280.0    2011-03-07 09:52:00         299
# 18281.0    2011-06-12 10:53:00         202
# 18282.0    2011-12-02 11:43:00          29
# 18283.0    2011-12-06 12:02:00          25
# 18287.0    2011-10-28 09:29:00          64
#
# [4372 rows x 2 columns]

# %% [markdown]
# ## Recency
# We already got the age of invoice

# %%
#recenccy

recency = maxdate.drop('InvoiceDate', axis=1)
recency
# Out:
#             InvoiceAge
# CustomerID
# 12346.0            347
# 12347.0             24
# 12348.0             97
# 12349.0             40
# 12350.0            332
# ...                ...
# 18280.0            299
# 18281.0            202
# 18282.0             29
# 18283.0             25
# 18287.0             64
#
# [4372 rows x 1 columns]

# %%
freq=df.drop_duplicates(subset="InvoiceNo")
freq
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 21        536368     22960             JAM MAKING SET WITH JARS         6
# 25        536369     21756             BATH BUILDING BLOCK WORD         3
# ...          ...       ...                                  ...       ...
# 541865    581583     20725              LUNCH BAG RED RETROSPOT        40
# 541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME        72
# 541869    581585     22481       BLACK TEA TOWEL CLASSIC DESIGN        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
freq = freq.groupby(["CustomerID"]).count()[["InvoiceNo"]]
freq
# Out:
#             InvoiceNo
# CustomerID
# 12346.0             2
# 12347.0             7
# 12348.0             4
# 12349.0             1
# 12350.0             1
# ...               ...
# 18280.0             1
# 18281.0             1
# 18282.0             3
# 18283.0            16
# 18287.0             3
#
# [4372 rows x 1 columns]

# %% [markdown]
# ## Monetary
# Total amount that a customer expences

# %%
#monetary
df["total"]=df["Quantity"]*df["UnitPrice"]

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  total
# ...

# %%
money=df.groupby(["CustomerID"])[["total"]].sum()
money
# Out:
#               total
# CustomerID
# 12346.0        0.00
# 12347.0     4310.00
# 12348.0     1797.24
# 12349.0     1757.55
# 12350.0      334.40
# ...             ...
# 18280.0      180.60
# 18281.0       80.82
# 18282.0      176.60
# 18283.0     2094.88
# 18287.0     1837.28
#
# [4372 rows x 1 columns]

# %%
df[df['CustomerID']==12346.0]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country    total
# 61619 2011-01-18 10:01:00       1.04     12346.0  United Kingdom  77183.6
# 61624 2011-01-18 10:17:00       1.04     12346.0  United Kingdom -77183.6

# %% [markdown]
# #### Now the total RFM comes out

# %%
RFM=pd.concat([recency,freq,money], axis=1)
RFM
# Out:
#             InvoiceAge  InvoiceNo    total
# CustomerID
# 12346.0            347          2     0.00
# 12347.0             24          7  4310.00
# 12348.0             97          4  1797.24
# 12349.0             40          1  1757.55
# 12350.0            332          1   334.40
# ...                ...        ...      ...
# 18280.0            299          1   180.60
# 18281.0            202          1    80.82
# 18282.0             29          3   176.60
# 18283.0             25         16  2094.88
# 18287.0             64          3  1837.28
#
# [4372 rows x 3 columns]

# %%
RFM.columns = ['Recency', 'Frequency', 'Monetary']
RFM
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         347          2      0.00
# 12347.0          24          7   4310.00
# 12348.0          97          4   1797.24
# 12349.0          40          1   1757.55
# 12350.0         332          1    334.40
# ...             ...        ...       ...
# 18280.0         299          1    180.60
# 18281.0         202          1     80.82
# 18282.0          29          3    176.60
# 18283.0          25         16   2094.88
# 18287.0          64          3   1837.28
#
# [4372 rows x 3 columns]

# %% [markdown]
# ### We already got the RFM now it's time to cluster
# #### Implemented K-Means Machine Learning Model To Cluster/Segment The Customers

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaled=scaler.fit_transform(RFM)

# %%
scaled
# Out:
# array([[ 2.31656788, -0.32936215, -0.23100099],
#        [-0.88904975,  0.20610242,  0.29343167],
#        [-0.16456032, -0.11517632, -0.01231622],
#        ...,
#        [-0.83942719, -0.22226923, -0.20951263],
#        [-0.87912524,  1.16993863,  0.02390005],
#        [-0.49206924, -0.22226923, -0.00744423]])

# %%
scaled.shape
# Out:
# (4372, 3)

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### To find out the value of K

# %%
k_range = range(1,10)
sse = []
for k in k_range:
    km = KMeans(n_clusters=k) 
    km.fit(scaled)
    sse.append(km.inertia_)
# Out:
# /home/oem/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/oem/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /home/oem/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
sse
# Out:
# [13116.000000000002,
#  9134.642381209182,
#  5527.705358813833,
#  4046.6395856924673,
#  3020.271453193467,
#  2369.972642559394,
#  1906.2234233786994,
#  1585.5649930710322,
#  1361.7238397824542]

# %%
plt.plot(k_range, sse, 'r-*')
plt.xlabel ='k'
plt.ylabel = 'Sum of Squared Error'

# %% [markdown]
# ### Object Creation and data fitting

# %%
kmeans=KMeans(n_clusters=3)
kmeans.fit(scaled)
# Out:
# /home/oem/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# KMeans(n_clusters=3)

# %%
kmeans.labels_
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
kmeans.labels_.shape
# Out:
# (4372,)

# %%
kmeans.labels_+1
# Out:
# array([2, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
RFM["Clusters"]=(kmeans.labels_+1)

# %%
RFM
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12346.0         347          2      0.00         2
# 12347.0          24          7   4310.00         1
# 12348.0          97          4   1797.24         1
# 12349.0          40          1   1757.55         1
# 12350.0         332          1    334.40         2
# ...             ...        ...       ...       ...
# 18280.0         299          1    180.60         2
# 18281.0         202          1     80.82         2
# 18282.0          29          3    176.60         1
# 18283.0          25         16   2094.88         1
# 18287.0          64          3   1837.28         1
#
# [4372 rows x 4 columns]

# %%
RFM.Clusters.unique()
# Out:
# array([2, 1, 3], dtype=int32)

# %%
RFM[RFM.Clusters==1]
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12347.0          24          7   4310.00         1
# 12348.0          97          4   1797.24         1
# 12349.0          40          1   1757.55         1
# 12352.0          58         11   1545.41         1
# 12356.0          44          3   2811.43         1
# ...             ...        ...       ...       ...
# 18277.0          80          2     97.63         1
# 18278.0          95          1    173.90         1
# 18282.0          29          3    176.60         1
# 18283.0          25         16   2094.88         1
# 18287.0          64          3   1837.28         1
#
# [3242 rows x 4 columns]

# %%
RFM[RFM.Clusters==2]
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12346.0         347          2      0.00         2
# 12350.0         332          1    334.40         2
# 12353.0         226          1     89.00         2
# 12354.0         254          1   1079.40         2
# 12355.0         236          1    459.40         2
# ...             ...        ...       ...       ...
# 18260.0         194          8   2595.00         2
# 18262.0         162          1    149.48         2
# 18269.0         380          2    138.90         2
# 18280.0         299          1    180.60         2
# 18281.0         202          1     80.82         2
#
# [1107 rows x 4 columns]

# %%
RFM[RFM.Clusters==3]
# Out:
#             Recency  Frequency   Monetary  Clusters
# CustomerID
# 12415.0          46         26  123725.45         3
# 12748.0          22        224   29072.10         3
# 12971.0          25         89   10930.26         3
# 13089.0          24        118   57385.88         3
# 13408.0          23         81   27487.41         3
# 13694.0          25         60   62653.10         3
# 13798.0          23         63   36351.42         3
# 14096.0          26         34   57120.91         3
# 14156.0          31         66  113384.14         3
# 14298.0          25         45   50862.44         3
# 14606.0          23        128   11713.85         3
# 14646.0          23         77  279489.02         3
# 14911.0          23        248  132572.62         3
# 15061.0          25         55   54228.74         3
# 15311.0          22        118   59419.34         3
# 16029.0          60         76   50992.61         3
# 16422.0          39         75   33805.69         3
# ...

# %%
final=RFM.groupby("Clusters").mean()[["Recency","Frequency","Monetary"]]
final
# Out:
#              Recency  Frequency      Monetary
# Clusters
# 1          61.560148   5.595620   1822.303551
# 2         267.719964   1.852755    460.644066
# 3          27.521739  86.869565  81835.857391

# %% [markdown]
# #### Let's segment customers

# %%
def func(row):
    if row["Clusters"]==3:
        return 'Dimond'
    elif row["Clusters"]==1:
        return 'Gold'
    else:
        return 'Silver'

# %%
RFM['group']=RFM.apply(func, axis=1)

# %%
RFM
# Out:
#             Recency  Frequency  Monetary  Clusters   group
# CustomerID
# 12346.0         347          2      0.00         2  Silver
# 12347.0          24          7   4310.00         1    Gold
# 12348.0          97          4   1797.24         1    Gold
# 12349.0          40          1   1757.55         1    Gold
# 12350.0         332          1    334.40         2  Silver
# ...             ...        ...       ...       ...     ...
# 18280.0         299          1    180.60         2  Silver
# 18281.0         202          1     80.82         2  Silver
# 18282.0          29          3    176.60         1    Gold
# 18283.0          25         16   2094.88         1    Gold
# 18287.0          64          3   1837.28         1    Gold
#
# [4372 rows x 5 columns]

# %%
result=RFM.group.value_counts()

# %%
result
# Out:
# group
# Gold      3242
# Silver    1107
# Dimond      23
# Name: count, dtype: int64

# %%
result.plot(kind="bar", color=["Orange","Red","Green"])
# Out:
# <Axes: xlabel='group'>

# %%
ABC = RFM[RFM.Clusters==3]

# %%
ABC[ABC['Monetary']==ABC['Monetary'].min()]
# Out:
#             Recency  Frequency  Monetary  Clusters   group
# CustomerID
# 12971.0          25         89  10930.26         3  Dimond

# %%
RFM[RFM.Clusters==1]
# Out:
#             Recency  Frequency  Monetary  Clusters group
# CustomerID
# 12347.0          24          7   4310.00         1  Gold
# 12348.0          97          4   1797.24         1  Gold
# 12349.0          40          1   1757.55         1  Gold
# 12352.0          58         11   1545.41         1  Gold
# 12356.0          44          3   2811.43         1  Gold
# ...             ...        ...       ...       ...   ...
# 18277.0          80          2     97.63         1  Gold
# 18278.0          95          1    173.90         1  Gold
# 18282.0          29          3    176.60         1  Gold
# 18283.0          25         16   2094.88         1  Gold
# 18287.0          64          3   1837.28         1  Gold
#
# [3242 rows x 5 columns]

# %% [markdown]
# ### RFM Segmentation Matrix

# %%
RFM['R_Score'] = pd.qcut(RFM['Recency'], q=3, labels=['High', 'Medium', 'Low'])
RFM['F_Score'] = pd.qcut(RFM['Frequency'], q=3, labels=['Low', 'Medium', 'High'])
RFM['M_Score'] = pd.qcut(RFM['Monetary'], q=3, labels=['Low', 'Medium', 'High'])

# %%
pd.qcut(RFM['Recency'], q=3, labels=['High', 'Medium', 'Low'])
# Out:
# CustomerID
# 12346.0       Low
# 12347.0      High
# 12348.0    Medium
# 12349.0      High
# 12350.0       Low
#             ...
# 18280.0       Low
# 18281.0       Low
# 18282.0      High
# 18283.0      High
# 18287.0    Medium
# Name: Recency, Length: 4372, dtype: category
# Categories (3, object): ['High' < 'Medium' < 'Low']

# %%
# Combine RFM scores
RFM['RFM_Segment'] = RFM['R_Score'].astype(str) + RFM['F_Score'].astype(str) + RFM['M_Score'].astype(str)

# %%
# Calculate RFM score
RFM['RFM_Score'] = RFM[['R_Score', 'F_Score', 'M_Score']].sum(axis=1)

# %% [markdown]
# #### R_score x F_score

# %%
# Create RFM segmentation matrix
rf_matrix = RFM.groupby(['R_Score', 'F_Score']).size().unstack()
sns.heatmap(rfm_matrix ,annot=True,fmt="d",cmap="Blues")
# Out:
# <Axes: xlabel='F_Score', ylabel='R_Score'>

# %% [markdown]
# #### R_score x M_score

# %%
rm_matrix = RFM.groupby(['R_Score', 'M_Score']).size().unstack()
sns.heatmap(rm_matrix ,annot=True,fmt="d",cmap="Blues")
# Out:
# <Axes: xlabel='M_Score', ylabel='R_Score'>

# %% [markdown]
# #### F_score x M_score

# %%
rm_matrix = RFM.groupby(['F_Score', 'M_Score']).size().unstack()
sns.heatmap(rm_matrix ,annot=True,fmt="d",cmap="Blues")
# Out:
# <Axes: xlabel='M_Score', ylabel='F_Score'>

# %% [markdown]
# ## RFM Heatmap
# Each cell in the heatmap represents a combination of RFM scores, and the color intensity indicates the frequency or monetary value associated with that combination. This helps identify segments of customers with different RFM characteristics.
